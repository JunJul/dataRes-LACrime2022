# %% [markdown]
# <a href="https://colab.research.google.com/github/JunJul/dataRes-LACrime2022/blob/Master/LACrime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file = "/content/drive/MyDrive/Colab Notebooks/la_crime_2010_to_2023.csv"
LACrime = pd.read_csv(file)

# %%
LACrime.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350   13.0
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45   14.0
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515   13.0
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150    6.0
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100    1.0
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ...   Status Desc  \
# 0                           VIOLATION OF COURT ORDER  ...  Adult Arrest
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...   Invest Cont
# ...

# %%
LACrime.tail()
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 2993428  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 2993429  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 2993430  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 2993431  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
# 2993432  230319786  11/10/2023 12:00:00 AM  11/09/2023 12:00:00 AM      2300
#
#          AREA     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 2993428    NaN     Foothill         1602         1     230
# 2993429    NaN  77th Street         1239         1     230
# 2993430    NaN      Central          154         1     352
# 2993431    NaN     Van Nuys          914         2     745
# 2993432    NaN    Southwest          395         1     331
#
#                                                Crm Cd Desc  ...  Status Desc  \
# ...

# %%
LACrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2993433 entries, 0 to 2993432
# Data columns (total 29 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   DR_NO           int64
#  1   Date Rptd       object
#  2   DATE OCC        object
#  3   TIME OCC        int64
#  4   AREA            float64
#  5   AREA NAME       object
#  6   Rpt Dist No     int64
#  7   Part 1-2        int64
#  8   Crm Cd          int64
#  9   Crm Cd Desc     object
#  10  Mocodes         object
#  11  Vict Age        int64
#  12  Vict Sex        object
#  13  Vict Descent    object
#  14  Premis Cd       float64
#  15  Premis Desc     object
#  16  Weapon Used Cd  float64
#  17  Weapon Desc     object
#  18  Status          object
#  19  Status Desc     object
#  20  Crm Cd 1        float64
#  21  Crm Cd 2        float64
#  22  Crm Cd 3        float64
#  23  Crm Cd 4        float64
#  24  LOCATION        object
#  25  Cross Street    object
#  26  LAT             float64
# ...

# %%
LACrime.describe()
# Out:
#               DR_NO      TIME OCC         AREA    Rpt Dist No      Part 1-2  \
# count  2.993433e+06  2.993433e+06  2.135775e+06  2.993433e+06  2.993433e+06
# mean   1.691583e+08  1.352589e+03  1.112354e+01  1.146872e+03  1.435812e+00
# std    4.032512e+07  6.491117e+02  6.008723e+00  6.037440e+02  4.958629e-01
# min    8.170000e+02  1.000000e+00  1.000000e+00  1.000000e+02  1.000000e+00
# 25%    1.317126e+08  9.160000e+02  6.000000e+00  6.380000e+02  1.000000e+00
# 50%    1.711210e+08  1.430000e+03  1.200000e+01  1.177000e+03  1.000000e+00
# 75%    2.020057e+08  1.900000e+03  1.600000e+01  1.659000e+03  2.000000e+00
# max    9.102204e+08  2.359000e+03  2.100000e+01  2.199000e+03  2.000000e+00
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  2.993433e+06  2.993433e+06  2.993376e+06    1.015019e+06  2.993412e+06
# mean   5.053445e+02  3.114550e+01  3.097565e+02    3.687495e+02  5.051395e+02
# ...

# %%
LACrime.columns.to_list()
# Out:
# ['DR_NO',
#  'Date Rptd',
#  'DATE OCC',
#  'TIME OCC',
#  'AREA ',
#  'AREA NAME',
#  'Rpt Dist No',
#  'Part 1-2',
#  'Crm Cd',
#  'Crm Cd Desc',
#  'Mocodes',
#  'Vict Age',
#  'Vict Sex',
#  'Vict Descent',
#  'Premis Cd',
#  'Premis Desc',
#  'Weapon Used Cd',
#  'Weapon Desc',
#  'Status',
#  'Status Desc',
#  'Crm Cd 1',
#  'Crm Cd 2',
#  'Crm Cd 3',
#  'Crm Cd 4',
#  'LOCATION',
#  'Cross Street',
#  'LAT',
#  'LON',
#  'AREA']

# %%
LACrime.columns = ['DR_NO', 'Date_Rptd', 'DATE_OCC', 'TIME_OCC',
  'AREA', 'AREA_NAME', 'Rpt_Dist_No', 'Part_1-2', 'Crm_Cd', 'Crm_Cd_Desc', 'Mocodes',
 'Vict_Age', 'Vict_Sex', 'Vict_Descent', 'Premis_Cd', 'Premis_Desc', 'Weapon_Used_Cd',
 'Weapon_Desc', 'Status', 'Status_Desc', 'Crm_Cd_1', 'Crm_Cd_2', 'Crm_Cd_3', 'Crm_Cd_4',
 'LOCATION', 'Cross_Street', 'LAT', 'LON', 'AREA']

# %%
LACrime.head()
# Out:
#        DR_NO               Date_Rptd                DATE_OCC  TIME_OCC  AREA  \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350  13.0
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45  14.0
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515  13.0
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150   6.0
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100   1.0
#
#    AREA_NAME  Rpt_Dist_No  Part_1-2  Crm_Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm_Cd_Desc  ...   Status_Desc  \
# 0                           VIOLATION OF COURT ORDER  ...  Adult Arrest
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...   Invest Cont
# ...

# %%
LACrime.AREA_NAME.value_counts()
# Out:
# AREA_NAME
# 77th Street    199626
# Southwest      183783
# Pacific        163041
# N Hollywood    157999
# Central        156659
# Southeast      155215
# Hollywood      144482
# Newton         143229
# Olympic        140546
# Devonshire     138429
# Northeast      137438
# Mission        136417
# Van Nuys       136185
# Topanga        132661
# Rampart        130184
# Wilshire       129761
# West LA        128819
# Harbor         127427
# West Valley    125961
# Foothill       115370
# Hollenbeck     110201
# Name: count, dtype: int64

# %%
len(LACrime.Crm_Cd_Desc.unique())
# Out:
# 143

# %%
LACrime["Status_Desc"].unique()
# Out:
# array(['Adult Arrest', 'Invest Cont', 'Adult Other', 'Juv Arrest',
#        'Juv Other', 'UNK'], dtype=object)

# %%
LACrime.groupby("AREA_NAME")["Status_Desc"].value_counts().sort_values(ascending=False).reset_index()
# Out:
#        AREA_NAME  Status_Desc   count
# 0    77th Street  Invest Cont  156817
# 1      Southwest  Invest Cont  142314
# 2        Pacific  Invest Cont  137754
# 3        Central  Invest Cont  128378
# 4      Southeast  Invest Cont  122507
# ..           ...          ...     ...
# 114    Northeast          UNK       1
# 115       Harbor          UNK       1
# 116      Mission          UNK       1
# 117     Van Nuys          UNK       1
# 118      Rampart          UNK       1
#
# [119 rows x 3 columns]

# %%
area_statusDesc_countdf2 = LACrime.groupby("AREA_NAME")["Status_Desc"].value_counts().unstack()
area_statusDesc_countdf2["Total_Case"] = np.sum(area_statusDesc_countdf2, axis=1)
area_statusDesc_countdf2 = area_statusDesc_countdf2.sort_values(by="Total_Case", ascending=False)
area_statusDesc_countdf2.head()
# Out:
# Status_Desc  Adult Arrest  Adult Other  Invest Cont  Juv Arrest  Juv Other  \
# AREA_NAME
# 77th Street       16250.0      24242.0     156817.0      1778.0      529.0
# Southwest         16944.0      22509.0     142314.0      1557.0      456.0
# Pacific           12174.0      12301.0     137754.0       586.0      223.0
# N Hollywood       18953.0      21034.0     117053.0       639.0      320.0
# Central           12179.0      15707.0     128378.0       322.0       69.0
#
# Status_Desc   UNK  Total_Case
# AREA_NAME
# 77th Street  10.0    199626.0
# Southwest     3.0    183783.0
# Pacific       3.0    163041.0
# N Hollywood   NaN    157999.0
# Central       4.0    156659.0

# %%
colors = ["#743838", "#526955", "#726767", "#3c3b49", "#632f42", "black"]

area_statusDesc_countdf2.iloc[:, :6].plot.bar(stacked=True, color=colors)
plt.legend(bbox_to_anchor = (1, 1), ncol = 2)
plt.title("Status Description Count vs Area Name in 2023")
plt.ylabel("Number of Cases")
plt.xlabel("Area Name")
plt.xticks(rotation=80)
plt.show()

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=area_statusDesc_countdf, x="count", y="AREA_NAME", hue="Status_Desc", orient="h")
plt.show()

# %%
import seaborn.objects as so

# %%
area_statusDesc_countdf = LACrime.groupby("AREA_NAME")["Status_Desc"].value_counts().unstack()
area_statusDesc_countdf["Total_Case"] = np.sum(area_statusDesc_countdf2, axis=1)
area_statusDesc_countdf = area_statusDesc_countdf.sort_values(by="Total_Case", ascending=False)
area_statusDesc_countdf.head()
# Out:
# Status_Desc  Adult Arrest  Adult Other  Invest Cont  Juv Arrest  Juv Other  \
# AREA_NAME
# 77th Street       16250.0      24242.0     156817.0      1778.0      529.0
# Southwest         16944.0      22509.0     142314.0      1557.0      456.0
# Pacific           12174.0      12301.0     137754.0       586.0      223.0
# N Hollywood       18953.0      21034.0     117053.0       639.0      320.0
# Central           12179.0      15707.0     128378.0       322.0       69.0
#
# Status_Desc   UNK  Total_Case
# AREA_NAME
# 77th Street  10.0    399252.0
# Southwest     3.0    367566.0
# Pacific       3.0    326082.0
# N Hollywood   NaN    315998.0
# Central       4.0    313318.0

# %%
# fig, ax = plt.subplots()
# ax.xaxis.set_tick_params(rotation=80)

# so.Plot(area_statusDesc_countdf,
#         x="AREA_NAME",
#         y = "count",
#         color="Status_Desc").add(so.Bar(), so.Stack()).on(ax).label(y="Area Name", x="Status Description Count",
#                                  title="Status Description Count vs Area Name in 2023")

# %% [markdown]
# Most cases in different area were in the invest continue in 2023, so these cases may not have the same status description in 2024.

# %%
crm_cd_desc_counts = LACrime["Crm_Cd_Desc"].value_counts()
crm_cd_desc_indices = np.array(crm_cd_desc_counts.index.copy())

# %% [markdown]
# Make the series into an numpy array to calculate the probability that a crime occur.

# %%
pro_crm_cd = np.multiply(np.divide(np.array(crm_cd_desc_counts), np.sum(crm_cd_desc_counts)), 100)
pro_ge_1_indices = np.array(np.where(pro_crm_cd > 1)[0])

# %%
origin_indices = crm_cd_desc_counts[pro_ge_1_indices].index

# %%
crm_cd_desc_indices[pro_ge_1_indices] = ['BATTERY-SIMPLE ASSAULT', 'VEHICLE-STOLEN', 'BURGLARY FROM VEHICLE',
                                              'BURGLARY', 'THEFT PLAIN', 'THEFT OF IDENTITY',
                                              'VANDALISM - FELONY', 'INTIMATE PARTNER - SIMPLE ASSAULT',
                                              'ASSAULT WITH DEADLY WEAPON',
                                              'THEFT FROM MOTOR VEHICLE', 'ROBBERY',
                                              'VANDALISM - MISDEAMEANOR',
                                              'THEFT-GRAND', 'CRIMINAL THREAT', 'SHOPLIFTING',
                                              'THEFT FROM MOTOR VEHICLE-GRAND', 'TRESPASSING',
                                              'VIOLATION OF RESTRAINING ORDER']

# %% [markdown]
# The red color emphasizes these crime cases have a greater probability occuring in LA than the green color.

# %%
legend_label = sorted(map(str, list(np.arange(1, 19))), key=int)
legend_label = [i + ": " for i in legend_label]
legend_label = [i + j for i, j in zip(legend_label, crm_cd_desc_indices[pro_ge_1_indices])]

# %%
not_improtant_cases_len = len(crm_cd_desc_indices) - len(pro_ge_1_indices)
important_cases_len = len(pro_ge_1_indices)

pie_colors = ["#743838"]*important_cases_len + ["#526955"]*not_improtant_cases_len
explode = [0.1]*important_cases_len + [0]*not_improtant_cases_len
labels = list(np.arange(1, 19)) + [""]*not_improtant_cases_len

plt.pie(pro_crm_cd, labels=labels,
        colors=pie_colors,
        explode=explode,
        #rotatelabels=90,
        textprops={'fontsize': 6},
        shadow=True,)

plt.legend(labels=legend_label, bbox_to_anchor = (1, 1), ncol = 2)
plt.title("The Most Frequent Crime Case in LA", pad=80)
plt.show()

# %%
frequentCrimeCase_names = list(origin_indices[pro_ge_1_indices])
frequentCrimeCase_df = LACrime[LACrime["Crm_Cd_Desc"].isin(frequentCrimeCase_names)]
frequentCrimeCase_df = frequentCrimeCase_df.reset_index(drop=True)

# %%
frequentCrimeCase_df.Weapon_Used_Cd = frequentCrimeCase_df.Weapon_Used_Cd.fillna(0)
frequentCrimeCase_df["weapon_used"] = pd.Series(np.where(frequentCrimeCase_df.Weapon_Used_Cd < 1, frequentCrimeCase_df.Weapon_Used_Cd, 1))

# %%
weapon_pro = frequentCrimeCase_df.groupby("Crm_Cd_Desc")["weapon_used"].agg(np.mean)
weapon_pro.index = ["ASSAULT WITH DEADLY WEAPON", 'BATTERY-SIMPLE ASSAULT', 'BURGLARY',
                    'BURGLARY FROM VEHICLE', 'CRIMINAL THREAT', 'INTIMATE PARTNER - SIMPLE ASSAULT',
                    'ROBBERY', 'SHOPLIFTING', 'THEFT FROM MOTOR VEHICLE-Grand',
                    "THEFT FROM MOTOR VEHICLE-Petty", 'THEFT OF IDENTITY', 'THEFT PLAIN-Petty',
                   'THEFT-GRAND', 'TRESPASSING', 'VANDALISM - FELONY', 'VANDALISM - MISDEAMEANOR',
                    'VEHICLE-STOLEN', 'VIOLATION OF RESTRAINING ORDER']

colors = ["#726767", "#726767", "#526955", "#526955", "#726767", "#726767","#726767"] + ["#526955"]*11
sns.barplot(x=weapon_pro, y=weapon_pro.index, palette=colors)
plt.xticks(rotation=85)
plt.title("The Probability of Weapon Used in each Crime Case")
plt.xlabel("Weapon Used Probability")
plt.ylabel("Crime Cases")
plt.xticks(rotation=0)
plt.show()
# Out:
# <ipython-input-68-289cb4452e08>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=weapon_pro, y=weapon_pro.index, palette=colors)

# %% [markdown]
# The salmon color emphasizes that the crime cases have an extremely high probability reported with weapons used.
